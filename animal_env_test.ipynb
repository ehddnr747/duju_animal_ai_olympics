# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from animalai.envs import UnityEnvironment
from animalai.envs import ArenaConfig

# %% [markdown]
# ## Arena Num and Action Dim check

# %%
env= UnityEnvironment(
        file_name='/home/duju/animal_ai_olympics/AnimalAI-Olympics/env/AnimalAI.x86_64',   # Path to the environment
        )
# Out:
# INFO:mlagents.envs:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of Training Brains : 1

# %%
A = env.reset(arenas_configurations=ArenaConfig("./configs/1-Food.yaml"))

# %%
action_dict = { 0 : np.array([1,0]), # forward
                1 : np.array([0,2]), # left
                2 : np.array([0,1]), # right
                3 : np.array([2,0]) # backward
                }

# %%
actions = [0]*400+[1]*400
np.random.shuffle(actions)

# %%
plt.imshow(A["Learner"].visual_observations[0][0])

# %%
count = 0

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

# %%
info.vector_observations[0]
# Out:
# array([0., 0., 0.])

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 52 * True * 2.3673717975616455

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 2 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 3 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 4 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 5 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 6 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 7 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 8 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 9 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 10 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 11 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 12 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 13 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 14 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 15 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 16 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 17 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 18 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 19 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 20 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 21 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 22 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 23 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 24 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 25 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 26 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 27 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 28 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 29 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 30 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 31 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 32 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 33 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 34 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 35 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 36 * False * -0.003999999724328518

# %%
a = action_dict[1]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 37 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 38 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 39 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 40 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 41 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 42 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 43 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 44 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 45 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 46 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 47 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 48 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 49 * False * -0.003999999724328518

# %%
a = action_dict[3]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 50 * False * -0.003999999724328518

# %%
a = action_dict[3]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 51 * False * -0.003999999724328518

# %%
a = action_dict[3]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 52 * False * -0.003999999724328518

# %%
for _ in range(180):
    a = action_dict[0]
    count += 1

    info = env.step([0,0])["Learner"]

    print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 53 * False * -0.003999999724328518
# 54 * False * -0.003999999724328518
# 55 * False * -0.003999999724328518
# 56 * False * -0.003999999724328518
# 57 * False * -0.003999999724328518
# 58 * False * -0.003999999724328518
# 59 * False * -0.003999999724328518
# 60 * False * -0.003999999724328518
# 61 * False * -0.003999999724328518
# 62 * False * -0.003999999724328518
# 63 * False * -0.003999999724328518
# 64 * False * -0.003999999724328518
# 65 * False * -0.003999999724328518
# 66 * False * -0.003999999724328518
# 67 * False * -0.003999999724328518
# 68 * False * -0.003999999724328518
# 69 * False * -0.003999999724328518
# 70 * False * -0.003999999724328518
# 71 * False * -0.003999999724328518
# 72 * False * -0.003999999724328518
# 73 * False * -0.003999999724328518
# 74 * False * -0.003999999724328518
# 75 * False * -0.003999999724328518
# 76 * False * -0.003999999724328518
# 77 * False * -0.003999999724328518
# 78 * False * -0.003999999724328518
# 79 * False * -0.003999999724328518
# ...

# %%
for _ in range(17):
    a = action_dict[0]
    count += 1

    info = env.step([0,0])["Learner"]

    print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 233 * False * -0.003999999724328518
# 234 * False * -0.003999999724328518
# 235 * False * -0.003999999724328518
# 236 * False * -0.003999999724328518
# 237 * False * -0.003999999724328518
# 238 * False * -0.003999999724328518
# 239 * False * -0.003999999724328518
# 240 * False * -0.003999999724328518
# 241 * False * -0.003999999724328518
# 242 * False * -0.003999999724328518
# 243 * False * -0.003999999724328518
# 244 * False * -0.003999999724328518
# 245 * False * -0.003999999724328518
# 246 * False * -0.003999999724328518
# 247 * False * -0.003999999724328518
# 248 * False * -0.003999999724328518
# 249 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 250 * False * -0.003999999724328518

# %%
a = action_dict[0]
count += 1

info = env.step(a)["Learner"]

print(count,"*",info.local_done[0],"*",info.rewards[0])
plt.imshow(info.visual_observations[0][0])
plt.show()
# Out:
# 251 * True * 2.3673717975616455

# %%
count = 0
for i in range(600):
    a = action_dict[actions[i]]
    count += 1
    
    info = env.step(a)["Learner"]
    
    print(count,"*",info.local_done[0],"*",info.rewards[0])
    plt.imshow(info.visual_observations[0][0])
    plt.show()

# %%
count = 0

# %%
info = env.step(action_dict[actions[count]])["Learner"]
count += 1

# %%
for i in range(1200):
    B = env.step([0,0])["Learner"]
    frames.append(B.visual_observations[0][0])
    print(i,B.local_done[0])

# %%
import cv2

# %%
t = ArenaConfig("./configs/4-Avoidance.yaml")

# %%
t.yaml_tag

# %%
T = A["Learner"]

# %%
frame = T.visual_observations[0][0]

# %%
(np.array(frame * 256, dtype=np.ubyte) / np.array([256],dtype=np.float32)).shape

# %%
plt.imshow(T.visual_observations[0][0][:,:,[2,1,0]])

# %%
B = env.step(vector_action=np.array([[0,1],[1,0],[0,1],[1,1]]))

# %%
T = B["Learner"]

# %%
T.visual_observations

# %%
frame.shape

# %%
T.local_done

# %%
np.max(T.visual_observations[0][0])

# %%
T.rewards

# %%
frame = B["Learner"].visual_observations
frame = np.array(frame)

plt.imshow(frame[0,3])

# %%
info = B["Learner"]

# %%
info.vector_observations

# %%
env.close()
